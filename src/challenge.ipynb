# %% [markdown]
# En este archivo puedes escribir lo que estimes conveniente. Te recomendamos detallar tu solución y todas las suposiciones que estás considerando. Aquí puedes ejecutar las funciones que definiste en los otros archivos de la carpeta src, medir el tiempo, memoria, etc.

# %% [markdown]
# **CARGA DE LIBRERÍAS Y FUNCIONES EXTERNAS**

# %%
# Importar funciones para cargar datos JSON y realizar análisis de memoria y tiempo
from load_json import cargar_datos_json  # Función para cargar datos JSON en un DataFrame
from q1_memory import q1_memory         # Función para encontrar las fechas con más tweets y los usuarios con más publicaciones (Optimización de memoria en uso)
from q1_time import q1_time             # Función para encontrar las fechas con más tweets y los usuarios con más publicaciones (Optimización de tiempo en ejecución)
from q2_memory import q2_memory         # Función para encontrar los emojis más usados y usuarios que los usan (Optimización de memoria en uso)
from q2_time import q2_time             # Función para encontrar los emojis más usados y usuarios que los usan (Optimización de tiempo en ejecución)
from q3_memory import q3_memory         # Función para encontrar los usuarios más influyentes por conteo de menciones (Optimización de memoria en uso)
from q3_time import q3_time             # Función para encontrar los usuarios más influyentes por conteo de menciones (Optimización de tiempo en ejecución)

# Importar pandas para manejo de datos
import pandas as pd

# Importar cProfile para realizar análisis de rendimiento
import cProfile

# %% [markdown]
# **CARGA DEL ARCHIVO FUENTE Y TRANSFORMACIÓN EN DATAFRAME**

# %%
# Especificar la ruta del archivo JSON que se va a cargar en el DataFrame
file_path = "farmers-protest-tweets-2021-2-4.json"

# Cargar los datos del archivo JSON en un DataFrame utilizando la función cargar_datos_json
# y convertirlo en un DataFrame de pandas
df = pd.DataFrame(cargar_datos_json(file_path))

# %% [markdown]
# **1.- TOP FECHA DÓNDE HAY MÁS TWEETS Y EL USUARIO CON MÁS TWEETS**

# %% [markdown]
# **ENFOQUE OPTIMIZACIÓN DE MEMORIA**

# %%
# Llamamos a la función pasándole como parámetro el DataFrame y guardando los resultados en top_dates
top_dates = q1_memory(df)
# Out:
# Filename: /Users/renatorivera/Documents/Python_Projects/latam-challenge/latam_challenge/src/q1_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      8   1671.5 MiB   1671.5 MiB           1   @profile
#      9                                         def q1_memory(df: pd.DataFrame) -> List[Tuple[datetime.date, str]]:
#     10                                             """
#     11                                             Encuentra las top 10 fechas con más tweets y el usuario con más tweets para cada una de esas fechas.
#     12
#     13                                             Args:
#     14                                             file_path (str): Ruta del archivo JSON.
#     15
#     16                                             Returns:
#     17                                             List[Tuple[datetime.date, str]]: Lista de tuplas que contiene la fecha y el usuario con más tweets.
#     18                                             """
#     19                                             # Cargar datos JSON en un DataFrame
#     20                                             #df = pd.DataFrame(cargar_datos_json(file_path))
#     21
#     22                                             # Convertir la columna 'date' a tipo datetime
#     23                                             #df['date'] = pd.to_datetime(df['date'])
#     24   1675.2 MiB      3.7 MiB           1       df['date'] = pd.to_datetime(df['date']).dt.date
#     25
#     26                                             # Obtener las top 10 fechas con más tweets
#     27                                             #top_10_fechas = df['date'].dt.date.value_counts().head(10).index
#     28   1675.5 MiB      0.4 MiB           1       top_10_fechas = df['date'].value_counts().nlargest(10).index
#     29
#     30   1675.5 MiB      0.0 MiB           1       resultados = []
#     31   1675.5 MiB      0.0 MiB           1       """
#     32                                             # Crear un DataFrame auxiliar para agrupar por fecha y usuario
#     33                                             aux_df = df.groupby(['date', df['user'].apply(lambda x: x['username'])]).size().reset_index(name='count')
#     34
#     35                                             # Encontrar el usuario con más tweets para cada fecha
#     36                                             max_tweets_idx = aux_df.groupby('date')['count'].idxmax()
#     37                                             top_users = aux_df.loc[max_tweets_idx]
#     38
#     39                                             # Crear la lista de resultados
#     40                                             resultados = list(zip(top_users['date'], top_users['user']))
#     41                                             """
#     42
#     43                                             # Para cada una de las top 10 fechas, obtener el usuario (username) que más publicaciones tiene
#     44   1675.7 MiB      0.0 MiB          11       for fecha in top_10_fechas:
#     45                                                 #tweets_en_fecha = df[df['date'].dt.date == fecha]
#     46   1675.7 MiB      0.1 MiB          10           tweets_en_fecha = df[df['date'] == fecha]
#     47   1675.7 MiB      0.1 MiB      198744           usuario_mas_tweets = tweets_en_fecha['user'].apply(lambda x: x['username']).value_counts().idxmax()
#     48   1675.7 MiB      0.0 MiB          10           resultados.append((fecha, usuario_mas_tweets))
#     49
#     50                                             #resultados = pd.DataFrame(resultados, columns=['Fecha', 'Usuario con más Tweets'])
#     51   1675.7 MiB      0.0 MiB           1       return resultados

# %% [markdown]
# El impacto en el uso de memoria es mayor después de la conversión de la columna 'date' a tipo datetime y la extracción de la fecha. Esto se refleja en un aumento de aproximadamente 4.7 MiB en el uso de memoria. Por otro lado, el cálculo de las 10 fechas con más tweets y la construcción de los resultados no tiene un impacto significativo en el uso de memoria, ya que el aumento es bastante pequeño (aproximadamente 0.1 MiB).

# %%
#Imprimimos el resultado
top_dates
# Out:
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'),
#  (datetime.date(2021, 2, 13), 'MaanDee08215437'),
#  (datetime.date(2021, 2, 17), 'RaaJVinderkaur'),
#  (datetime.date(2021, 2, 16), 'jot__b'),
#  (datetime.date(2021, 2, 14), 'rebelpacifist'),
#  (datetime.date(2021, 2, 18), 'neetuanjle_nitu'),
#  (datetime.date(2021, 2, 15), 'jot__b'),
#  (datetime.date(2021, 2, 20), 'MangalJ23056160'),
#  (datetime.date(2021, 2, 23), 'Surrypuria'),
#  (datetime.date(2021, 2, 19), 'Preetm91')]

# %% [markdown]
# **ENFOQUE DE OPTIMIZACIÓN EN TIEMPO**

# %%
#Creamos una función para controlar el tiempo de ejecución de la función q1_time
def profile_q1_time():
    cProfile.run('q1_time(df)', sort='cumulative')

# Ejecutar el profiler
profile_q1_time()
# Out:
#          114345 function calls (113921 primitive calls) in 0.153 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        11    0.000    0.000    0.045    0.004 base.py:891(_map_values)
#        11    0.019    0.002    0.045    0.004 algorithms.py:1667(map_array)
#        10    0.000    0.000    0.041    0.004 common.py:62(new_method)
#        10    0.000    0.000    0.040    0.004 arraylike.py:38(__eq__)
#        10    0.000    0.000    0.040    0.004 series.py:6101(_cmp_method)
#        10    0.000    0.000    0.040    0.004 array_ops.py:288(comparison_op)
#        10    0.040    0.004    0.040    0.004 array_ops.py:113(comp_method_OBJECT_ARRAY)
#        10    0.000    0.000    0.036    0.004 series.py:4780(apply)
#        10    0.000    0.000    0.036    0.004 apply.py:1409(apply)
#        10    0.000    0.000    0.036    0.004 apply.py:1482(apply_standard)
#     44/43    0.000    0.000    0.026    0.001 take.py:59(take_nd)
#        11    0.000    0.000    0.022    0.002 base.py:923(value_counts)
#        11    0.000    0.000    0.022    0.002 algorithms.py:862(value_counts_internal)
#        32    0.000    0.000    0.019    0.001 frame.py:4050(__getitem__)
#        11    0.018    0.002    0.018    0.002 algorithms.py:963(value_counts_arraylike)
#        10    0.000    0.000    0.017    0.002 frame.py:4118(_getitem_bool_array)
#   891/886    0.000    0.000    0.017    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.017    0.017 decorator.py:229(fun)
#         1    0.000    0.000    0.017    0.017 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.017    0.017 history.py:845(writeout_cache)
#        11    0.000    0.000    0.017    0.002 generic.py:4139(_take_with_is_copy)
#         1    0.000    0.000    0.016    0.016 history.py:833(_writeout_input_cache)
#         2    0.016    0.008    0.016    0.008 {method '__exit__' of 'sqlite3.Connection' objects}
#        11    0.000    0.000    0.016    0.001 generic.py:4024(take)
#        11    0.000    0.000    0.016    0.001 managers.py:869(take)
#     99367    0.016    0.000    0.016    0.000 q1_time.py:31(<lambda>)
#        12    0.000    0.000    0.016    0.001 managers.py:623(reindex_indexer)
#        42    0.000    0.000    0.015    0.000 blocks.py:1287(take_nd)
#        43    0.014    0.000    0.015    0.000 take.py:120(_take_nd_ndarray)
#         1    0.000    0.000    0.011    0.011 series.py:4611(map)
#         1    0.000    0.000    0.011    0.011 _mixins.py:157(take)
#         2    0.000    0.000    0.006    0.003 base_events.py:1908(_run_once)
#         2    0.000    0.000    0.006    0.003 algorithms.py:1131(take)
#         3    0.000    0.000    0.004    0.001 base.py:3820(get_indexer)
#         1    0.000    0.000    0.004    0.004 algorithms.py:307(unique)
#         1    0.004    0.004    0.004    0.004 algorithms.py:427(unique_with_mask)
#        47    0.001    0.000    0.004    0.000 series.py:389(__init__)
#         1    0.003    0.003    0.003    0.003 base.py:3955(_get_indexer)
#        11    0.000    0.000    0.002    0.000 series.py:3678(sort_values)
#        60    0.000    0.000    0.002    0.000 construction.py:517(sanitize_array)
#         1    0.000    0.000    0.001    0.001 frame.py:4259(__setitem__)
#         1    0.000    0.000    0.001    0.001 frame.py:4502(_set_item)
#        11    0.000    0.000    0.001    0.000 sorting.py:369(nargsort)
#        25    0.001    0.000    0.001    0.000 cast.py:1157(maybe_infer_to_datetimelike)
#        81    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#        14    0.000    0.000    0.001    0.000 base.py:475(__new__)
# 3219/3172    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.001    0.000 base.py:6394(_should_compare)
#         1    0.000    0.000    0.001    0.001 frame.py:4469(_set_item_mgr)
#         3    0.001    0.000    0.001    0.000 base.py:2744(inferred_type)
#         1    0.000    0.000    0.001    0.001 frame.py:4458(_iset_item_mgr)
#         1    0.000    0.000    0.001    0.001 frame.py:4611(_clear_item_cache)
#         1    0.001    0.001    0.001    0.001 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.001    0.001 series.py:4145(nlargest)
#         1    0.000    0.000    0.001    0.001 selectn.py:55(nlargest)
#         1    0.000    0.000    0.001    0.001 selectn.py:90(compute)
#        10    0.000    0.000    0.001    0.000 series.py:6192(_construct_result)
#        12    0.001    0.000    0.001    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#        22    0.000    0.000    0.001    0.000 frame.py:4614(_get_item_cache)
#         1    0.000    0.000    0.001    0.001 datetimes.py:209(_maybe_cache)
#       120    0.000    0.000    0.000    0.000 generic.py:6298(__setattr__)
#        95    0.000    0.000    0.000    0.000 base.py:7593(ensure_index)
#        11    0.000    0.000    0.000    0.000 frame.py:3971(_ixs)
#        10    0.000    0.000    0.000    0.000 indexing.py:2632(check_bool_indexer)
#        47    0.000    0.000    0.000    0.000 managers.py:1861(from_array)
#        43    0.000    0.000    0.000    0.000 base.py:5373(__getitem__)
#        23    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 frame.py:5229(_sanitize_column)
#         2    0.000    0.000    0.000    0.000 {method 'run' of '_contextvars.Context' objects}
#        22    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 frame.py:12662(_reindex_for_setitem)
#       545    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#        10    0.000    0.000    0.000    0.000 utils.py:419(check_array_indexer)
#   151/141    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#  1068/711    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        59    0.000    0.000    0.000    0.000 generic.py:6233(__finalize__)
#        36    0.000    0.000    0.000    0.000 numeric.py:274(full)
#         3    0.000    0.000    0.000    0.000 base.py:6679(_maybe_cast_listlike_indexer)
#        10    0.000    0.000    0.000    0.000 series.py:2682(idxmax)
#         1    0.000    0.000    0.000    0.000 utils.py:187(validate_indices)
#        67    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        67    0.000    0.000    0.000    0.000 generic.py:6281(__getattr__)
#         1    0.000    0.000    0.000    0.000 datetimes.py:314(_convert_listlike_datetimes)
#        46    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#        43    0.000    0.000    0.000    0.000 take.py:564(_take_preprocess_indexer_and_fill_value)
#         1    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#        10    0.000    0.000    0.000    0.000 range.py:1148(take)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:718(<lambda>)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:607(_handle_events)
#         1    0.000    0.000    0.000    0.000 series.py:5250(drop)
#         1    0.000    0.000    0.000    0.000 generic.py:4754(drop)
#         2    0.000    0.000    0.000    0.000 datetimes.py:320(__new__)
#         1    0.000    0.000    0.000    0.000 generic.py:4793(_drop_axis)
#        11    0.000    0.000    0.000    0.000 utils.py:239(maybe_convert_indices)
#        11    0.000    0.000    0.000    0.000 frame.py:4596(_box_col_values)
#        44    0.000    0.000    0.000    0.000 cast.py:551(maybe_promote)
#         1    0.000    0.000    0.000    0.000 concat.py:157(concat)
#        11    0.000    0.000    0.000    0.000 {method 'min' of 'numpy.ndarray' objects}
#        73    0.000    0.000    0.000    0.000 generic.py:278(__init__)
#       545    0.000    0.000    0.000    0.000 generic.py:37(_check)
#        11    0.000    0.000    0.000    0.000 _methods.py:43(_amin)
#         1    0.000    0.000    0.000    0.000 datetimes.py:149(should_cache)
#        57    0.000    0.000    0.000    0.000 series.py:780(name)
#         2    0.000    0.000    0.000    0.000 datetimes.py:329(_from_sequence_not_strict)
#        14    0.000    0.000    0.000    0.000 common.py:231(asarray_tuplesafe)
#         2    0.000    0.000    0.000    0.000 indexing.py:1176(__getitem__)
#        11    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#        22    0.000    0.000    0.000    0.000 common.py:97(is_bool_indexer)
#        10    0.000    0.000    0.000    0.000 base.py:680(argmax)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:687(_rebuild_io_state)
#        23    0.000    0.000    0.000    0.000 missing.py:101(isna)
#         1    0.000    0.000    0.000    0.000 datetimes.py:259(_box_as_indexlike)
#        47    0.000    0.000    0.000    0.000 generic.py:806(_set_axis)
#        11    0.000    0.000    0.000    0.000 _methods.py:39(_amax)
#         2    0.000    0.000    0.000    0.000 indexing.py:1719(_getitem_axis)
#         3    0.000    0.000    0.000    0.000 attrsettr.py:42(__getattr__)
#        41    0.000    0.000    0.000    0.000 base.py:649(_simple_new)
#         1    0.000    0.000    0.000    0.000 concat.py:622(get_result)
#        23    0.000    0.000    0.000    0.000 missing.py:184(_isna)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:710(_update_handler)
#        83    0.000    0.000    0.000    0.000 series.py:730(name)
#        20    0.000    0.000    0.000    0.000 base.py:5437(_can_hold_identifiers_and_holds_name)
#        46    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#       123    0.000    0.000    0.000    0.000 series.py:703(dtype)
#        47    0.000    0.000    0.000    0.000 blocks.py:2716(new_block)
#        13    0.000    0.000    0.000    0.000 socket.py:621(send)
#        11    0.000    0.000    0.000    0.000 managers.py:1012(iget)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:648(_handle_recv)
#        44    0.000    0.000    0.000    0.000 common.py:137(is_object_dtype)
#        11    0.000    0.000    0.000    0.000 frame.py:672(_constructor_sliced_from_mgr)
#        10    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 attrsettr.py:65(_get_attr_opt)
#        57    0.000    0.000    0.000    0.000 common.py:1571(validate_all_hashable)
#        23    0.000    0.000    0.000    0.000 base.py:5323(__contains__)
#        26    0.000    0.000    0.000    0.000 generic.py:339(_from_mgr)
#        74    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#        73    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000    0.000    0.000 base.py:7031(drop)
#        10    0.000    0.000    0.000    0.000 _methods.py:61(_all)
#        12    0.000    0.000    0.000    0.000 algorithms.py:106(_ensure_data)
#        35    0.000    0.000    0.000    0.000 common.py:1198(is_bool_dtype)
#         1    0.000    0.000    0.000    0.000 indexing.py:1696(_get_list_axis)
#       123    0.000    0.000    0.000    0.000 managers.py:1991(dtype)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:580(_run_callback)
#       3/1    0.005    0.002    0.000    0.000 events.py:86(_run)
#        35    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 accessors.py:70(_get_values)
#        53    0.000    0.000    0.000    0.000 common.py:1434(_is_dtype_type)
#         1    0.000    0.000    0.000    0.000 concat.py:699(new_axes)
#        11    0.000    0.000    0.000    0.000 missing.py:261(_isna_array)
#        48    0.000    0.000    0.000    0.000 blocks.py:2645(maybe_coerce_values)
#        10    0.000    0.000    0.000    0.000 frame.py:659(_constructor_from_mgr)
#        22    0.000    0.000    0.000    0.000 common.py:536(is_string_dtype)
#         1    0.000    0.000    0.000    0.000 algorithms.py:262(_get_hashtable_algo)
#        28    0.000    0.000    0.000    0.000 common.py:1375(_is_dtype)
#         1    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#        47    0.000    0.000    0.000    0.000 managers.py:236(set_axis)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         1    0.000    0.000    0.000    0.000 iostream.py:276(<lambda>)
#         1    0.000    0.000    0.000    0.000 concat.py:717(_get_concat_axis)
#         1    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#        11    0.000    0.000    0.000    0.000 generic.py:510(_validate_dtype)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2184(_sequence_to_dt64)
#         1    0.000    0.000    0.000    0.000 concat.py:777(_concat_indexes)
#         2    0.000    0.000    0.000    0.000 managers.py:708(_slice_take_blocks_ax0)
#        43    0.000    0.000    0.000    0.000 take.py:325(_get_take_nd_function)
#         1    0.000    0.000    0.000    0.000 base.py:5455(append)
#        14    0.000    0.000    0.000    0.000 inference.py:273(is_dict_like)
#         1    0.000    0.000    0.000    0.000 socket.py:698(send_multipart)
#        35    0.000    0.000    0.000    0.000 _methods.py:55(_any)
#        10    0.000    0.000    0.000    0.000 nanops.py:1109(nanargmax)
#        46    0.000    0.000    0.000    0.000 config.py:635(_get_root)
#         1    0.000    0.000    0.000    0.000 base.py:5491(_concat)
#        24    0.000    0.000    0.000    0.000 common.py:1596(pandas_dtype)
#        45    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#         2    0.000    0.000    0.000    0.000 base.py:2313(is_unique)
#        87    0.000    0.000    0.000    0.000 series.py:827(_values)
#       164    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         1    0.000    0.000    0.000    0.000 base.py:674(_with_infer)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#        47    0.000    0.000    0.000    0.000 base.py:86(_validate_set_axis)
#        25    0.000    0.000    0.000    0.000 series.py:910(__len__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 managers.py:557(copy)
#        11    0.000    0.000    0.000    0.000 warnings.py:166(simplefilter)
#        12    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#        32    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        59    0.000    0.000    0.000    0.000 construction.py:693(_sanitize_ndim)
#         6    0.000    0.000    0.000    0.000 _dtype.py:346(_name_get)
#        11    0.000    0.000    0.000    0.000 frame.py:669(_sliced_from_mgr)
#         1    0.000    0.000    0.000    0.000 algorithms.py:280(_check_object_for_strings)
#        12    0.000    0.000    0.000    0.000 base.py:5552(equals)
#         3    0.000    0.000    0.000    0.000 datetimes.py:2428(maybe_convert_dtype)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#       140    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        13    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#        11    0.000    0.000    0.000    0.000 _validators.py:354(validate_ascending)
#        22    0.000    0.000    0.000    0.000 common.py:572(condition)
#        95    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#        14    0.000    0.000    0.000    0.000 base.py:82(shape)
#        12    0.000    0.000    0.000    0.000 algorithms.py:184(_reconstruct_data)
#         1    0.000    0.000    0.000    0.000 series.py:5811(dropna)
#         1    0.000    0.000    0.000    0.000 datetimes.py:2354(objects_to_datetime64)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#        42    0.000    0.000    0.000    0.000 blocks.py:292(make_block_same_class)
#        48    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#       177    0.000    0.000    0.000    0.000 base.py:909(__len__)
#         1    0.000    0.000    0.000    0.000 base.py:6162(get_indexer_for)
#        34    0.000    0.000    0.000    0.000 indexing.py:2765(check_dict_or_set_indexers)
#         1    0.000    0.000    0.000    0.000 take.py:287(_get_take_nd_function_cached)
#        46    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#         1    0.000    0.000    0.000    0.000 concat.py:405(__init__)
#        11    0.000    0.000    0.000    0.000 common.py:1277(is_extension_array_dtype)
#        11    0.000    0.000    0.000    0.000 warnings.py:182(_add_filter)
#         2    0.000    0.000    0.000    0.000 base.py:842(_engine)
#        12    0.000    0.000    0.000    0.000 fromnumeric.py:1881(nonzero)
#         1    0.000    0.000    0.000    0.000 managers.py:1066(iset)
#        22    0.000    0.000    0.000    0.000 inference.py:195(is_array_like)
#       129    0.000    0.000    0.000    0.000 range.py:999(__len__)
#        80    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         1    0.000    0.000    0.000    0.000 generic.py:6659(copy)
#        87    0.000    0.000    0.000    0.000 managers.py:2002(internal_values)
#       114    0.000    0.000    0.000    0.000 common.py:1590(<genexpr>)
#        26    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#        10    0.000    0.000    0.000    0.000 apply.py:1377(__init__)
#       222    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 accessor.py:220(__get__)
#         1    0.000    0.000    0.000    0.000 base.py:6916(delete)
#        85    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:558(_validate_scalar)
#        57    0.000    0.000    0.000    0.000 construction.py:732(_sanitize_str_dtypes)
#         1    0.000    0.000    0.000    0.000 cast.py:606(_maybe_promote_cached)
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#        25    0.000    0.000    0.000    0.000 base.py:74(__len__)
#        22    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#         2    0.000    0.000    0.000    0.000 managers.py:317(apply)
#         1    0.000    0.000    0.000    0.000 indexing.py:1756(_get_slice_axis)
#        10    0.000    0.000    0.000    0.000 managers.py:948(from_blocks)
#        25    0.000    0.000    0.000    0.000 warnings.py:482(__enter__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 base_events.py:836(call_soon_threadsafe)
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#        12    0.000    0.000    0.000    0.000 algorithms.py:217(_ensure_arraylike)
#         1    0.000    0.000    0.000    0.000 accessors.py:611(__new__)
#         5    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#        12    0.000    0.000    0.000    0.000 fromnumeric.py:53(_wrapfunc)
#        73    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#         5    0.000    0.000    0.000    0.000 series.py:664(_constructor_from_mgr)
#        26    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:2423(ensure_arraylike_for_datetimelike)
#         2    0.000    0.000    0.000    0.000 extension.py:67(fget)
#        63    0.000    0.000    0.000    0.000 common.py:1399(_get_dtype)
#        39    0.000    0.000    0.000    0.000 base.py:84(<genexpr>)
#       189    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         3    0.000    0.000    0.000    0.000 common.py:1163(is_float_dtype)
#         1    0.000    0.000    0.000    0.000 socket.py:777(recv_multipart)
#        10    0.000    0.000    0.000    0.000 function.py:124(validate_argmax_with_skipna)
#        22    0.000    0.000    0.000    0.000 generic.py:585(_get_axis)
#        10    0.000    0.000    0.000    0.000 construction.py:763(_try_cast)
#         1    0.000    0.000    0.000    0.000 series.py:1078(_slice)
#        11    0.000    0.000    0.000    0.000 series.py:1462(_set_as_cached)
#        59    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#        10    0.000    0.000    0.000    0.000 {method 'argmax' of 'numpy.ndarray' objects}
#        46    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#        33    0.000    0.000    0.000    0.000 inference.py:300(<genexpr>)
#        28    0.000    0.000    0.000    0.000 common.py:1331(is_ea_or_datetimelike_dtype)
#        68    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1044c0a48}
#         2    0.000    0.000    0.000    0.000 common.py:633(is_integer_dtype)
#        25    0.000    0.000    0.000    0.000 warnings.py:503(__exit__)
#        10    0.000    0.000    0.000    0.000 common.py:81(get_op_result_name)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#        46    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 missing.py:673(na_value_for_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:1081(is_numeric_dtype)
#         2    0.000    0.000    0.000    0.000 base.py:6415(_is_comparable_dtype)
#         1    0.000    0.000    0.000    0.000 cast.py:614(_maybe_promote)
#        11    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 missing.py:728(is_valid_na_for_dtype)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#        10    0.000    0.000    0.000    0.000 series.py:974(__array__)
#        59    0.000    0.000    0.000    0.000 construction.py:752(_maybe_repeat)
#         6    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#        42    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#        12    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         2    0.000    0.000    0.000    0.000 base_events.py:812(_call_soon)
#        10    0.000    0.000    0.000    0.000 dispatch.py:17(should_extension_dispatch)
#        35    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#        10    0.000    0.000    0.000    0.000 generic.py:4376(_set_is_copy)
#         3    0.000    0.000    0.000    0.000 base.py:5170(_get_engine_target)
#        73    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 base.py:1146(take)
#         2    0.000    0.000    0.000    0.000 base.py:6324(_maybe_downcast_for_indexing)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#        25    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#         2    0.000    0.000    0.000    0.000 datetimes.py:304(_simple_new)
#        11    0.000    0.000    0.000    0.000 blocks.py:1253(iget)
#        58    0.000    0.000    0.000    0.000 generic.py:571(_get_axis_number)
#         1    0.000    0.000    0.000    0.000 function_base.py:5173(delete)
#        10    0.000    0.000    0.000    0.000 common.py:992(is_numeric_v_string_like)
#        48    0.000    0.000    0.000    0.000 common.py:123(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2351(copy)
#        33    0.000    0.000    0.000    0.000 common.py:529(is_string_or_object_np_dtype)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#        11    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 api.py:386(default_index)
#         6    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#        10    0.000    0.000    0.000    0.000 nanops.py:253(_get_values)
#        11    0.000    0.000    0.000    0.000 base.py:1686(name)
#         1    0.000    0.000    0.000    0.000 take.py:353(wrapper)
#        11    0.000    0.000    0.000    0.000 generic.py:591(_get_block_manager_axis)
#        46    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#         1    0.000    0.000    0.000    0.000 datetimes.py:525(_unbox_scalar)
#        12    0.000    0.000    0.000    0.000 base.py:791(is_)
#       119    0.000    0.000    0.000    0.000 generic.py:404(flags)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:357(issubdtype)
#        25    0.000    0.000    0.000    0.000 warnings.py:456(__init__)
#        14    0.000    0.000    0.000    0.000 common.py:1040(needs_i8_conversion)
#        36    0.000    0.000    0.000    0.000 blocks.py:718(dtype)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 cast.py:1516(construct_1d_arraylike_from_scalar)
#         2    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#         1    0.000    0.000    0.000    0.000 accessors.py:59(__init__)
#        60    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#        63    0.000    0.000    0.000    0.000 managers.py:1835(__init__)
#        21    0.000    0.000    0.000    0.000 range.py:553(equals)
#        22    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         1    0.000    0.000    0.000    0.000 managers.py:1972(get_slice)
#        12    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        21    0.000    0.000    0.000    0.000 generic.py:666(_info_axis)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.000    0.000 base_events.py:783(call_soon)
#        59    0.000    0.000    0.000    0.000 generic.py:362(attrs)
#         3    0.000    0.000    0.000    0.000 typing.py:378(inner)
#        48    0.000    0.000    0.000    0.000 common.py:121(classes)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:566(sending)
#         1    0.000    0.000    0.000    0.000 managers.py:583(copy_func)
#         1    0.000    0.000    0.000    0.000 managers.py:1265(_iset_single)
#        14    0.000    0.000    0.000    0.000 base.py:591(_ensure_array)
#         2    0.000    0.000    0.000    0.000 concat.py:52(concat_compat)
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.datetime_data}
#        14    0.000    0.000    0.000    0.000 base.py:609(_dtype_to_subclass)
#         1    0.000    0.000    0.000    0.000 range.py:201(_simple_new)
#         3    0.000    0.000    0.000    0.000 base.py:3996(_check_indexing_method)
#       101    0.000    0.000    0.000    0.000 typing.py:2132(cast)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 base.py:675(empty)
#        32    0.000    0.000    0.000    0.000 common.py:152(cast_scalar_indexer)
#        23    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         2    0.000    0.000    0.000    0.000 blocks.py:790(copy)
#         2    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 datetimes.py:835(_local_timestamps)
#         1    0.000    0.000    0.000    0.000 concat.py:545(_get_sample_object)
#         1    0.000    0.000    0.000    0.000 concat.py:494(_clean_keys_and_objs)
#         3    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 selectn.py:63(is_valid_dtype_n_method)
#         1    0.000    0.000    0.000    0.000 datetimes.py:1436(date)
#         2    0.000    0.000    0.000    0.000 queue.py:97(empty)
#        20    0.000    0.000    0.000    0.000 __init__.py:55(using_pyarrow_string_dtype)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 base.py:448(size)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:283(issubclass_)
#         4    0.000    0.000    0.000    0.000 managers.py:1848(from_blocks)
#        10    0.000    0.000    0.000    0.000 apply.py:121(__init__)
#         3    0.000    0.000    0.000    0.000 base_events.py:732(time)
#         1    0.000    0.000    0.000    0.000 concat.py:480(_get_ndims)
#         1    0.000    0.000    0.000    0.000 datetimes.py:126(_guess_datetime_format_for_array)
#        61    0.000    0.000    0.000    0.000 managers.py:1938(_block)
#         4    0.000    0.000    0.000    0.000 base.py:2776(_is_multi)
#         1    0.000    0.000    0.000    0.000 common.py:301(maybe_iterable_to_list)
#        10    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 base.py:1010(view)
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.generic' objects}
#        22    0.000    0.000    0.000    0.000 managers.py:180(blknos)
#        70    0.000    0.000    0.000    0.000 base.py:363(ndim)
#         3    0.000    0.000    0.000    0.000 blocks.py:253(fill_value)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#        61    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#        37    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#        70    0.000    0.000    0.000    0.000 range.py:376(dtype)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2310(_construct_from_dt64_naive)
#         1    0.000    0.000    0.000    0.000 blocks.py:2703(new_block_2d)
#         1    0.000    0.000    0.000    0.000 blocks.py:2811(ensure_block_shape)
#         6    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         2    0.000    0.000    0.000    0.000 blocks.py:2795(extend_blocks)
#        21    0.000    0.000    0.000    0.000 managers.py:196(blklocs)
#        38    0.000    0.000    0.000    0.000 series.py:660(_constructor)
#        18    0.000    0.000    0.000    0.000 datetimes.py:551(dtype)
#        10    0.000    0.000    0.000    0.000 function.py:104(process_skipna)
#         2    0.000    0.000    0.000    0.000 _dtype.py:178(_datetime_metadata_str)
#        39    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#        16    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 numeric.py:136(ones)
#         5    0.000    0.000    0.000    0.000 common.py:131(<lambda>)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         4    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:319(asi8)
#         1    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2150(unit)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#        48    0.000    0.000    0.000    0.000 series.py:1471(_clear_item_cache)
#         2    0.000    0.000    0.000    0.000 base.py:7723(_unpack_nested_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:773(_view)
#        10    0.000    0.000    0.000    0.000 nanops.py:209(_maybe_get_mask)
#         3    0.000    0.000    0.000    0.000 base.py:166(__setattr__)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         2    0.000    0.000    0.000    0.000 base.py:456(_engine_type)
#        25    0.000    0.000    0.000    0.000 managers.py:246(items)
#         1    0.000    0.000    0.000    0.000 series.py:698(_can_hold_na)
#         1    0.000    0.000    0.000    0.000 base.py:5425(_getitem_slice)
#        21    0.000    0.000    0.000    0.000 function.py:64(__call__)
#         2    0.000    0.000    0.000    0.000 managers.py:2318(_preprocess_slice_or_indexer)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 base.py:4191(_validate_positional_slice)
#         1    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         1    0.000    0.000    0.000    0.000 generic.py:4399(_check_setitem_copy)
#         6    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#        11    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 base.py:346(shape)
#         1    0.000    0.000    0.000    0.000 base.py:549(find)
#         2    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         1    0.000    0.000    0.000    0.000 managers.py:2015(_can_hold_na)
#        12    0.000    0.000    0.000    0.000 base.py:692(_constructor)
#        21    0.000    0.000    0.000    0.000 base.py:5144(_values)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 common.py:1342(is_complex_dtype)
#        16    0.000    0.000    0.000    0.000 base.py:1671(name)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#        15    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         5    0.000    0.000    0.000    0.000 common.py:126(_classes_and_not_datetimelike)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2535(dtype_to_unit)
#         1    0.000    0.000    0.000    0.000 series.py:861(_references)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 datetimes.py:103(tz_to_dtype)
#        10    0.000    0.000    0.000    0.000 generic.py:695(ndim)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#        10    0.000    0.000    0.000    0.000 function.py:383(validate_minmax_axis)
#         3    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 indexing.py:161(iloc)
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 frame.py:4573(_ensure_valid_index)
#         2    0.000    0.000    0.000    0.000 indexing.py:1165(_check_deprecated_callable_usage)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#        11    0.000    0.000    0.000    0.000 base.py:1176(_maybe_disallow_fill)
#         3    0.000    0.000    0.000    0.000 generic.py:6274(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         3    0.000    0.000    0.000    0.000 common.py:1270(is_1d_only_ea_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:86(consensus_name_attr)
#         1    0.000    0.000    0.000    0.000 frame.py:1631(__len__)
#         3    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 generic.py:6267(<genexpr>)
#         2    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         3    0.000    0.000    0.000    0.000 common.py:1194(<lambda>)
#        12    0.000    0.000    0.000    0.000 fromnumeric.py:1877(_nonzero_dispatcher)
#        10    0.000    0.000    0.000    0.000 range.py:315(step)
#         4    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        13    0.000    0.000    0.000    0.000 multiarray.py:153(concatenate)
#         4    0.000    0.000    0.000    0.000 datetimelike.py:2041(freq)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 blocks.py:230(_can_hold_na)
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:2061(_maybe_pin_freq)
#         1    0.000    0.000    0.000    0.000 selectn.py:44(__init__)
#         1    0.000    0.000    0.000    0.000 cast.py:525(ensure_dtype_can_hold_na)
#         1    0.000    0.000    0.000    0.000 base.py:2794(_na_value)
#        10    0.000    0.000    0.000    0.000 range.py:280(start)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         3    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 generic.py:579(_get_axis_name)
#        10    0.000    0.000    0.000    0.000 frame.py:655(_constructor)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:62(is_list_like_indexer)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        10    0.000    0.000    0.000    0.000 nanops.py:1431(_maybe_arg_null_out)
#        10    0.000    0.000    0.000    0.000 managers.py:913(__init__)
#         2    0.000    0.000    0.000    0.000 common.py:1122(<lambda>)
#         4    0.000    0.000    0.000    0.000 base.py:6312(_index_as_unique)
#         1    0.000    0.000    0.000    0.000 datetimes.py:576(tz)
#         3    0.000    0.000    0.000    0.000 base.py:6685(_validate_indexer)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 concat.py:693(_get_result_dim)
#        12    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#         7    0.000    0.000    0.000    0.000 managers.py:1826(ndim)
#         4    0.000    0.000    0.000    0.000 datetimes.py:2570(_validate_tz_from_dtype)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2146(_creso)
#         3    0.000    0.000    0.000    0.000 common.py:178(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 base.py:159(_freeze)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:562(receiving)
#         1    0.000    0.000    0.000    0.000 common.py:174(not_none)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         2    0.000    0.000    0.000    0.000 datetimes.py:217(_scalar_type)
#         2    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 indexing.py:2752(need_slice)
#         3    0.000    0.000    0.000    0.000 base_events.py:2003(get_debug)
#         1    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         2    0.000    0.000    0.000    0.000 base_events.py:538(_check_closed)
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 datetimes.py:2514(_validate_dt64_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:686(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         3    0.000    0.000    0.000    0.000 missing.py:1073(clean_reindex_fill_method)
#         1    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 managers.py:1987(index)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 concat.py:770(_maybe_check_integrity)
#         1    0.000    0.000    0.000    0.000 base_events.py:718(is_closed)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 datetimes.py:537(_check_compatible_with)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getrefcount}
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 base.py:323(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 function_base.py:5169(_delete_dispatcher)
#       1/0    0.000    0.000    0.000          {method 'control' of 'select.kqueue' objects}
#       1/0    0.000    0.000    0.000          selectors.py:558(select)

# %% [markdown]
# El tiempo de ejecución es menor a 0.16 s.

# %%
#Llamamos a la función e imprimimos el resultado
q1_time(df)
# Out:
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'),
#  (datetime.date(2021, 2, 13), 'MaanDee08215437'),
#  (datetime.date(2021, 2, 17), 'RaaJVinderkaur'),
#  (datetime.date(2021, 2, 16), 'jot__b'),
#  (datetime.date(2021, 2, 14), 'rebelpacifist'),
#  (datetime.date(2021, 2, 18), 'neetuanjle_nitu'),
#  (datetime.date(2021, 2, 15), 'jot__b'),
#  (datetime.date(2021, 2, 20), 'MangalJ23056160'),
#  (datetime.date(2021, 2, 23), 'Surrypuria'),
#  (datetime.date(2021, 2, 19), 'Preetm91')]

# %% [markdown]
# **2.- TOP 10 EMOJIS MÁS USADOS Y SU RESPECTIVO CONTEO**

# %% [markdown]
# **ENFOQUE OPTIMIZACIÓN DE MEMORIA**

# %%
q2_memory(df)
# Out:
# Filename: /Users/renatorivera/Documents/Python_Projects/latam-challenge/latam_challenge/src/q2_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     10   1684.0 MiB   1684.0 MiB           1   @profile
#     11                                         def q2_memory(df: pd.DataFrame) -> List[Tuple[str, int]]:
#     12                                             """
#     13                                             Encuentra los top 10 emojis más usados, la cantidad de veces que se utilizan y el nombre del usuario que lo utilizó.
#     14
#     15                                             Args:
#     16                                             df (pd.DataFrame): DataFrame que contiene los datos del archivo JSON.
#     17
#     18                                             Returns:
#     19                                             List[Tuple[str, int]]: Lista de tuplas que contiene el emoji y la cantidad de veces que se utiliza.
#     20                                             """
#     21                                             # Inicializar un diccionario para almacenar la frecuencia de cada emoji
#     22   1684.0 MiB      0.0 MiB           1       emoji_frequency = Counter()
#     23
#     24                                             # Iterar sobre las filas del DataFrame
#     25   1692.0 MiB -13428871.8 MiB      117408       for index, row in df.iterrows():
#     26                                                 # Obtener el texto del tweet
#     27   1692.0 MiB -13428621.1 MiB      117407           tweet_text = row['content']
#     28
#     29                                                 # Extraer emojis del texto del tweet y actualizar el contador
#     30   1692.0 MiB -13428734.0 MiB      117407           emojis_found = extract_emojis(tweet_text)
#     31   1692.0 MiB -13428759.9 MiB      117407           emoji_frequency.update(emojis_found)
#     32
#     33                                             # Obtener los 10 emojis más comunes
#     34   1422.8 MiB   -269.2 MiB           1       top_10_emojis = emoji_frequency.most_common(10)
#     35
#     36   1422.8 MiB      0.0 MiB           1       return top_10_emojis
# [('🙏', 7286),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('✊', 2411),
#  ('🌾', 2363),
#  ('🇮', 2096),
#  ('🇳', 2094),
#  ('❤', 1779),
#  ('🤣', 1668),
#  ('👇', 1108)]

# %% [markdown]
# Se debe reemplazar el ciclo for por métodos vectorizados.

# %% [markdown]
# **ENFOQUE DE OPTIMIZACIÓN EN TIEMPO**

# %%
#Creamos una función para controlar el tiempo de ejecución de la función q2_time
def profile_q2_time():
    cProfile.run('q2_time(df)', sort='cumulative')

# Ejecutar el profiler
profile_q2_time()
# Out:
#          2818381 function calls (2818373 primitive calls) in 0.760 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.760    0.760 {built-in method builtins.exec}
#         1    0.000    0.000    0.760    0.760 <string>:1(<module>)
#         1    0.036    0.036    0.757    0.757 q2_time.py:7(q2_time)
#    117407    0.033    0.000    0.628    0.000 extract_emojis.py:3(extract_emojis)
#    117407    0.039    0.000    0.490    0.000 regex.py:349(compile)
#    117407    0.149    0.000    0.451    0.000 regex.py:449(_compile)
#    234821    0.106    0.000    0.216    0.000 enum.py:1541(__and__)
#    117407    0.106    0.000    0.106    0.000 {method 'findall' of '_regex.Pattern' objects}
# 704526/704522    0.067    0.000    0.096    0.000 {built-in method builtins.isinstance}
#    117408    0.027    0.000    0.094    0.000 __init__.py:668(update)
#    234843    0.043    0.000    0.072    0.000 enum.py:713(__call__)
#    117412    0.031    0.000    0.048    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#    117407    0.015    0.000    0.029    0.000 <frozen abc>:117(__instancecheck__)
#    234843    0.029    0.000    0.029    0.000 enum.py:1116(__new__)
#    117407    0.026    0.000    0.026    0.000 regex.py:471(complain_unused_args)
#    117407    0.016    0.000    0.016    0.000 {built-in method _collections._count_elements}
#    117407    0.015    0.000    0.015    0.000 {built-in method _abc._abc_instancecheck}
#    117412    0.012    0.000    0.012    0.000 {method 'get' of 'dict' objects}
#    117417    0.010    0.000    0.010    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.003    0.003 decorator.py:229(fun)
#         1    0.000    0.000    0.003    0.003 history.py:55(only_when_enabled)
#         3    0.000    0.000    0.001    0.000 base_events.py:1908(_run_once)
#         1    0.000    0.000    0.001    0.001 history.py:845(writeout_cache)
#       4/3    0.000    0.000    0.001    0.000 events.py:86(_run)
#       4/3    0.000    0.000    0.001    0.000 {method 'run' of '_contextvars.Context' objects}
#         2    0.000    0.000    0.001    0.000 zmqstream.py:607(_handle_events)
#         1    0.000    0.000    0.001    0.001 asyncio.py:200(_handle_events)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:648(_handle_recv)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:580(_run_callback)
#         2    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#         2    0.000    0.000    0.000    0.000 iostream.py:276(<lambda>)
#         2    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:687(_rebuild_io_state)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:42(__getattr__)
#         1    0.000    0.000    0.000    0.000 frame.py:4050(__getitem__)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:65(_get_attr_opt)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:710(_update_handler)
#         2    0.000    0.000    0.000    0.000 socket.py:698(send_multipart)
#        14    0.000    0.000    0.000    0.000 socket.py:621(send)
#         1    0.000    0.000    0.000    0.000 frame.py:4614(_get_item_cache)
#         1    0.000    0.000    0.000    0.000 frame.py:3971(_ixs)
#         1    0.000    0.000    0.000    0.000 __init__.py:618(most_common)
#         1    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:718(<lambda>)
#         1    0.000    0.000    0.000    0.000 heapq.py:523(nlargest)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#       3/2    0.000    0.000    0.000    0.000 selectors.py:558(select)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         1    0.000    0.000    0.000    0.000 frame.py:4596(_box_col_values)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#        15    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         2    0.000    0.000    0.000    0.000 socket.py:777(recv_multipart)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 frame.py:672(_constructor_sliced_from_mgr)
#         1    0.000    0.000    0.000    0.000 managers.py:1012(iget)
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#         1    0.000    0.000    0.000    0.000 frame.py:669(_sliced_from_mgr)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#       2/1    0.000    0.000    0.000    0.000 {method 'control' of 'select.kqueue' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:836(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 generic.py:339(_from_mgr)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:566(sending)
#         1    0.000    0.000    0.000    0.000 generic.py:6233(__finalize__)
#         3    0.000    0.000    0.000    0.000 base_events.py:812(_call_soon)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         3    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         6    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 base_events.py:783(call_soon)
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 base.py:5323(__contains__)
#         1    0.000    0.000    0.000    0.000 concurrent.py:181(future_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         1    0.000    0.000    0.000    0.000 generic.py:278(__init__)
#         1    0.000    0.000    0.000    0.000 history.py:833(_writeout_input_cache)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         4    0.000    0.000    0.000    0.000 generic.py:6298(__setattr__)
#         2    0.000    0.000    0.000    0.000 base.py:5373(__getitem__)
#         1    0.000    0.000    0.000    0.000 __init__.py:595(__init__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         3    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         3    0.000    0.000    0.000    0.000 series.py:827(_values)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         4    0.000    0.000    0.000    0.000 base_events.py:732(time)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         6    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 series.py:1462(_set_as_cached)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         1    0.000    0.000    0.000    0.000 blocks.py:1253(iget)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         3    0.000    0.000    0.000    0.000 managers.py:2002(internal_values)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 indexing.py:2765(check_dict_or_set_indexers)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         3    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         2    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         8    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         7    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        24    0.000    0.000    0.000    0.000 typing.py:2132(cast)
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         3    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         4    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 common.py:152(cast_scalar_indexer)
#         6    0.000    0.000    0.000    0.000 {built-in method _heapq.heapreplace}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 base_events.py:1893(_add_callback)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:562(receiving)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 managers.py:180(blknos)
#         1    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         5    0.000    0.000    0.000    0.000 base_events.py:2003(get_debug)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 managers.py:1835(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:196(blklocs)
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1044c0a48}
#         3    0.000    0.000    0.000    0.000 base_events.py:538(_check_closed)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 generic.py:404(flags)
#         1    0.000    0.000    0.000    0.000 generic.py:362(attrs)
#         1    0.000    0.000    0.000    0.000 managers.py:1938(_block)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 base_events.py:718(is_closed)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)

# %% [markdown]
# El tiempo de ejecución es menor a 0.7 s

# %%
q2_time(df)
# Out:
# [('🙏', 7286),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('✊', 2411),
#  ('🌾', 2363),
#  ('🇮', 2096),
#  ('🇳', 2094),
#  ('❤', 1779),
#  ('🤣', 1668),
#  ('👇', 1108)]

# %% [markdown]
# **3.- TOP 10 USUARIOS MÁS MENCIONADOS Y SU RESPECTIVO NÚMERO DE VECES**

# %% [markdown]
# **ENFOQUE OPTIMIZACIÓN MEMORIA EN USO**

# %%
q3_memory(df)
# Out:
# Filename: /Users/renatorivera/Documents/Python_Projects/latam-challenge/latam_challenge/src/q3_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      5   1433.8 MiB   1433.8 MiB           1   @profile
#      6                                         def q3_memory(df: pd.DataFrame) -> List[Tuple[str, int]]:
#      7                                             # Inicializar un diccionario para almacenar el conteo de menciones de cada usuario
#      8   1433.8 MiB      0.0 MiB           1       mention_count = {}
#      9
#     10                                             # Iterar sobre cada fila del DataFrame
#     11   1468.9 MiB -195354.3 MiB      117408       for index, row in df.iterrows():
#     12                                                 # Obtener la lista de usuarios mencionados en el tweet
#     13   1468.9 MiB -195357.6 MiB      117407           mentions = row['mentionedUsers']
#     14   1468.9 MiB -195358.4 MiB      117407           if mentions:
#     15                                                     # Iterar sobre cada usuario mencionado y actualizar su conteo
#     16   1468.9 MiB -222191.6 MiB      141437               for user in mentions:
#     17   1468.9 MiB -161584.0 MiB      103403                   username = user['username']
#     18   1468.9 MiB -161593.6 MiB      103403                   mention_count[username] = mention_count.get(username, 0) + 1
#     19
#     20                                             # Ordenar el diccionario por los conteos de menciones en orden descendente
#     21   1445.4 MiB    -23.5 MiB       30479       sorted_mentions = sorted(mention_count.items(), key=lambda x: x[1], reverse=True)
#     22
#     23                                             # Tomar los 10 usuarios más mencionados
#     24   1445.4 MiB      0.0 MiB           1       top_10_mentions = sorted_mentions[:10]
#     25
#     26   1445.4 MiB      0.0 MiB           1       return top_10_mentions
# [('narendramodi', 2265),
#  ('Kisanektamorcha', 1840),
#  ('RakeshTikaitBKU', 1644),
#  ('PMOIndia', 1427),
#  ('RahulGandhi', 1146),
#  ('GretaThunberg', 1048),
#  ('RaviSinghKA', 1019),
#  ('rihanna', 986),
#  ('UNHumanRights', 962),
#  ('meenaharris', 926)]

# %% [markdown]
# En instancias distribuidas es posible implementar el procesamiento en lotes.

# %% [markdown]
# **ENFOQUE OPTIMIZACIÓN EN TIEMPO**

# %%
#Creamos una función para controlar el tiempo de ejecución de la función q3_time
def profile_q3_time():
    cProfile.run('q3_time(df)', sort='cumulative')

# Ejecutar el profiler
profile_q3_time()
# Out:
#          104591 function calls (104537 primitive calls) in 0.096 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.086    0.086 {built-in method builtins.exec}
#         1    0.001    0.001    0.086    0.086 <string>:1(<module>)
#         1    0.001    0.001    0.085    0.085 q3_time.py:6(q3_time)
#         1    0.000    0.000    0.059    0.059 series.py:4780(apply)
#         1    0.001    0.001    0.059    0.059 apply.py:1409(apply)
#         1    0.000    0.000    0.031    0.031 apply.py:1482(apply_standard)
#         1    0.000    0.000    0.031    0.031 base.py:891(_map_values)
#         1    0.020    0.020    0.031    0.031 algorithms.py:1667(map_array)
#         1    0.000    0.000    0.026    0.026 series.py:5811(dropna)
#         1    0.000    0.000    0.026    0.026 missing.py:718(remove_na_arraylike)
#         3    0.000    0.000    0.026    0.009 base_events.py:1908(_run_once)
#       4/2    0.000    0.000    0.024    0.012 events.py:86(_run)
#       4/2    0.000    0.000    0.024    0.012 {method 'run' of '_contextvars.Context' objects}
#         2    0.003    0.002    0.024    0.012 zmqstream.py:607(_handle_events)
#         2    0.000    0.000    0.024    0.012 __init__.py:668(update)
#         1    0.000    0.000    0.024    0.024 asyncio.py:200(_handle_events)
#         1    0.024    0.024    0.024    0.024 {built-in method _collections._count_elements}
#         2    0.000    0.000    0.020    0.010 zmqstream.py:648(_handle_recv)
#         2    0.000    0.000    0.020    0.010 iostream.py:276(<lambda>)
#         2    0.000    0.000    0.020    0.010 iostream.py:278(_really_send)
#         2    0.000    0.000    0.020    0.010 socket.py:698(send_multipart)
#         2    0.019    0.009    0.019    0.009 {method 'recv' of '_socket.socket' objects}
#    103403    0.011    0.000    0.011    0.000 q3_time.py:14(<lambda>)
#        14    0.000    0.000    0.010    0.001 socket.py:621(send)
#         1    0.010    0.010    0.010    0.010 missing.py:101(isna)
#         1    0.000    0.000    0.010    0.010 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.002    0.002 series.py:1086(__getitem__)
#         1    0.000    0.000    0.001    0.001 __init__.py:618(most_common)
#         1    0.001    0.001    0.001    0.001 heapq.py:523(nlargest)
#         1    0.000    0.000    0.001    0.001 series.py:4487(explode)
#         1    0.000    0.000    0.001    0.001 series.py:1207(_get_rows_with_mask)
#         3    0.001    0.000    0.001    0.000 base.py:5373(__getitem__)
#         1    0.000    0.000    0.001    0.001 managers.py:1952(get_rows_with_mask)
#         1    0.000    0.000    0.000    0.000 base.py:1238(repeat)
#         2    0.000    0.000    0.000    0.000 series.py:389(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 construction.py:517(sanitize_array)
#         2    0.000    0.000    0.000    0.000 cast.py:1157(maybe_infer_to_datetimelike)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:580(_run_callback)
#         2    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:42(__getattr__)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:687(_rebuild_io_state)
#         1    0.000    0.000    0.000    0.000 decorator.py:229(fun)
#         1    0.000    0.000    0.000    0.000 history.py:55(only_when_enabled)
#   201/197    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         5    0.000    0.000    0.000    0.000 attrsettr.py:65(_get_attr_opt)
#         1    0.000    0.000    0.000    0.000 history.py:845(writeout_cache)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:710(_update_handler)
#         1    0.000    0.000    0.000    0.000 frame.py:4050(__getitem__)
#         1    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:718(<lambda>)
#         1    0.000    0.000    0.000    0.000 frame.py:4614(_get_item_cache)
#         3    0.000    0.000    0.000    0.000 numeric.py:274(full)
#         1    0.000    0.000    0.000    0.000 _methods.py:47(_sum)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 frame.py:3971(_ixs)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         7    0.000    0.000    0.000    0.000 generic.py:6298(__setattr__)
#       2/1    0.002    0.001    0.000    0.000 selectors.py:558(select)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         1    0.000    0.000    0.000    0.000 history.py:833(_writeout_input_cache)
#       9/8    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         1    0.000    0.000    0.000    0.000 missing.py:184(_isna)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#      17/3    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 missing.py:261(_isna_array)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#      17/3    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 frame.py:4596(_box_col_values)
#        15    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         2    0.000    0.000    0.000    0.000 managers.py:1861(from_array)
#         4    0.000    0.000    0.000    0.000 generic.py:6281(__getattr__)
#     63/48    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         3    0.000    0.000    0.000    0.000 generic.py:6233(__finalize__)
#         2    0.000    0.000    0.000    0.000 common.py:97(is_bool_indexer)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         2    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#         2    0.000    0.000    0.000    0.000 socket.py:777(recv_multipart)
#         1    0.000    0.000    0.000    0.000 function.py:64(__call__)
#         1    0.000    0.000    0.000    0.000 indexing.py:2632(check_bool_indexer)
#        29    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 base_events.py:836(call_soon_threadsafe)
#       2/1    0.000    0.000    0.000    0.000 {method 'control' of 'select.kqueue' objects}
#         1    0.000    0.000    0.000    0.000 series.py:664(_constructor_from_mgr)
#         4    0.000    0.000    0.000    0.000 generic.py:278(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:672(_constructor_sliced_from_mgr)
#         2    0.000    0.000    0.000    0.000 base.py:649(_simple_new)
#         1    0.000    0.000    0.000    0.000 _validators.py:168(validate_args_and_kwargs)
#         2    0.000    0.000    0.000    0.000 generic.py:339(_from_mgr)
#         1    0.000    0.000    0.000    0.000 managers.py:1012(iget)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         4    0.000    0.000    0.000    0.000 common.py:137(is_object_dtype)
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         2    0.000    0.000    0.000    0.000 base.py:5437(_can_hold_identifiers_and_holds_name)
#        16    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#         7    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         2    0.000    0.000    0.000    0.000 series.py:780(name)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 missing.py:305(_isna_string_dtype)
#         1    0.000    0.000    0.000    0.000 frame.py:669(_sliced_from_mgr)
#         3    0.000    0.000    0.000    0.000 series.py:730(name)
#         3    0.000    0.000    0.000    0.000 common.py:1198(is_bool_dtype)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#         1    0.000    0.000    0.000    0.000 utils.py:419(check_array_indexer)
#         3    0.000    0.000    0.000    0.000 base_events.py:812(_call_soon)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         2    0.000    0.000    0.000    0.000 blocks.py:2716(new_block)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#        16    0.000    0.000    0.000    0.000 generic.py:37(_check)
#         6    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         4    0.000    0.000    0.000    0.000 series.py:703(dtype)
#         2    0.000    0.000    0.000    0.000 generic.py:806(_set_axis)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         4    0.000    0.000    0.000    0.000 common.py:1434(_is_dtype_type)
#         2    0.000    0.000    0.000    0.000 common.py:1571(validate_all_hashable)
#         2    0.000    0.000    0.000    0.000 series.py:910(__len__)
#        32    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 zmqstream.py:566(sending)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         4    0.000    0.000    0.000    0.000 managers.py:1991(dtype)
#         2    0.000    0.000    0.000    0.000 common.py:536(is_string_dtype)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#        29    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         1    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#         2    0.000    0.000    0.000    0.000 base_events.py:783(call_soon)
#         3    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         1    0.000    0.000    0.000    0.000 inference.py:273(is_dict_like)
#         2    0.000    0.000    0.000    0.000 config.py:635(_get_root)
#         2    0.000    0.000    0.000    0.000 blocks.py:2645(maybe_coerce_values)
#         1    0.000    0.000    0.000    0.000 _validators.py:141(validate_kwargs)
#         1    0.000    0.000    0.000    0.000 concurrent.py:181(future_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 apply.py:1377(__init__)
#         4    0.000    0.000    0.000    0.000 base_events.py:732(time)
#         2    0.000    0.000    0.000    0.000 common.py:1375(_is_dtype)
#         6    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         1    0.000    0.000    0.000    0.000 base.py:5323(__contains__)
#         1    0.000    0.000    0.000    0.000 missing.py:380(notna)
#         6    0.000    0.000    0.000    0.000 series.py:827(_values)
#         2    0.000    0.000    0.000    0.000 base.py:74(__len__)
#         2    0.000    0.000    0.000    0.000 managers.py:236(set_axis)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 series.py:698(_can_hold_na)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 managers.py:2015(_can_hold_na)
#         2    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         3    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         6    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 blocks.py:1253(iget)
#         5    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         2    0.000    0.000    0.000    0.000 indexing.py:2765(check_dict_or_set_indexers)
#         2    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#         2    0.000    0.000    0.000    0.000 common.py:572(condition)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         1    0.000    0.000    0.000    0.000 __init__.py:595(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         6    0.000    0.000    0.000    0.000 managers.py:2002(internal_values)
#         2    0.000    0.000    0.000    0.000 base.py:86(_validate_set_axis)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#        20    0.000    0.000    0.000    0.000 {built-in method _heapq.heapreplace}
#         1    0.000    0.000    0.000    0.000 series.py:974(__array__)
#         2    0.000    0.000    0.000    0.000 construction.py:693(_sanitize_ndim)
#        10    0.000    0.000    0.000    0.000 base.py:909(__len__)
#         1    0.000    0.000    0.000    0.000 series.py:1462(_set_as_cached)
#         2    0.000    0.000    0.000    0.000 construction.py:732(_sanitize_str_dtypes)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         5    0.000    0.000    0.000    0.000 common.py:1399(_get_dtype)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         2    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         4    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 _validators.py:128(_check_for_invalid_keys)
#         3    0.000    0.000    0.000    0.000 blocks.py:718(dtype)
#         1    0.000    0.000    0.000    0.000 blocks.py:230(_can_hold_na)
#         4    0.000    0.000    0.000    0.000 common.py:123(<lambda>)
#         4    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#         3    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         4    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1044c0a48}
#         2    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#         2    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         1    0.000    0.000    0.000    0.000 base.py:5144(_values)
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        27    0.000    0.000    0.000    0.000 typing.py:2132(cast)
#         3    0.000    0.000    0.000    0.000 common.py:529(is_string_or_object_np_dtype)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 inference.py:300(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _validators.py:29(_check_arg_length)
#         4    0.000    0.000    0.000    0.000 common.py:1590(<genexpr>)
#         8    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#        15    0.000    0.000    0.000    0.000 <frozen _collections_abc>:435(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#         7    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         4    0.000    0.000    0.000    0.000 common.py:121(classes)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         2    0.000    0.000    0.000    0.000 inference.py:195(is_array_like)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         5    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         6    0.000    0.000    0.000    0.000 generic.py:404(flags)
#         1    0.000    0.000    0.000    0.000 _validators.py:49(_check_for_default_values)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 base.py:7593(ensure_index)
#         2    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#         2    0.000    0.000    0.000    0.000 generic.py:666(_info_axis)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 apply.py:121(__init__)
#         3    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 range.py:999(__len__)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#         1    0.000    0.000    0.000    0.000 managers.py:180(blknos)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 __init__.py:55(using_pyarrow_string_dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 construction.py:752(_maybe_repeat)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         4    0.000    0.000    0.000    0.000 managers.py:1835(__init__)
#         1    0.000    0.000    0.000    0.000 common.py:1596(pandas_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:692(_constructor)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         3    0.000    0.000    0.000    0.000 generic.py:362(attrs)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:562(receiving)
#         2    0.000    0.000    0.000    0.000 common.py:152(cast_scalar_indexer)
#         1    0.000    0.000    0.000    0.000 generic.py:571(_get_axis_number)
#         3    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#         2    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#         3    0.000    0.000    0.000    0.000 series.py:660(_constructor)
#         1    0.000    0.000    0.000    0.000 base_events.py:1893(_add_callback)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         4    0.000    0.000    0.000    0.000 managers.py:1938(_block)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 base.py:1671(name)
#         3    0.000    0.000    0.000    0.000 base_events.py:538(_check_closed)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 managers.py:246(items)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 managers.py:196(blklocs)
#         5    0.000    0.000    0.000    0.000 base_events.py:2003(get_debug)
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 managers.py:1987(index)
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         2    0.000    0.000    0.000    0.000 series.py:1471(_clear_item_cache)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         1    0.000    0.000    0.000    0.000 base_events.py:718(is_closed)
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)

# %% [markdown]
# El tiempo de ejecución es menor a 0.1 s

# %%
q3_time(df)
# Out:
# [('narendramodi', 2265),
#  ('Kisanektamorcha', 1840),
#  ('RakeshTikaitBKU', 1644),
#  ('PMOIndia', 1427),
#  ('RahulGandhi', 1146),
#  ('GretaThunberg', 1048),
#  ('RaviSinghKA', 1019),
#  ('rihanna', 986),
#  ('UNHumanRights', 962),
#  ('meenaharris', 926)]
